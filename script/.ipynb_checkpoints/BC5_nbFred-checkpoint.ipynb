# %%
import pandas as pd
import numpy as np
import datetime as dt

import seaborn as sns
import matplotlib.pyplot as plt
import calmap
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
path = r'C:/Users/frede/Documents/GitHub/BC5_Demand_Forecast/data/MindOverData_RetailChallenge.csv'
pathPP = r'C:/Users/frede/Documents/GitHub/BC5_Demand_Forecast/data/values_units.csv'

# %%
# 20 M
data =  pd.read_csv(path, nrows=1999998)

# %%
#PreProcessing - removing excessive letters from the variables

data['ProductFamily_ID'] = data['ProductFamily_ID'].str.split('_').str[1]
data['ProductCategory_ID'] = data['ProductCategory_ID'].str.split('_').str[1]
data['ProductBrand_ID'] = data['ProductBrand_ID'].str.split('_').str[1]
data['ProductName_ID'] = data['ProductName_ID'].str.split('_').str[1]
data['ProductPackSKU_ID'] = data['ProductPackSKU_ID'].str.split('_').str[1]
data['Point-of-Sale_ID'] = data['Point-of-Sale_ID'].str.split('_').str[1]

data['Measures'] = data['Measures'].str.split(' ').str[1]

data.head(20)
# Out:
#    ProductFamily_ID ProductCategory_ID ProductBrand_ID ProductName_ID  \
# 0                16                 11             306            649
# 1                16                 11             306            649
# 2                16                 11             306            649
# 3                16                 11             306            649
# 4                16                 11             306            649
# 5                16                 11             306            649
# 6                16                 11             306            649
# 7                16                 11             306            649
# 8                16                 11             306            649
# 9                16                 11             306            649
# 10               16                 11             306            649
# 11               16                 11             306            649
# 12               16                 11             306            649
# 13               16                 11             306            649
# 14               16                 11             306            649
# 15               16                 11             306            649
# 16               16                 11             306            649
# 17               16                 11             306            649
# 18               16                 11             306            649
# 19               16                 11             306            649
#
#    ProductPackSKU_ID Point-of-Sale_ID        Date Measures   Value
# 0               1970                1  2017-03-04    units     2.0
# 1               1970                1  2017-03-04   values  1540.0
# 2               1970                1  2016-05-02    units     4.0
# 3               1970                1  2016-05-02   values  3080.0
# 4               1970                1  2016-10-24    units     2.0
# 5               1970                1  2016-10-24   values  1540.0
# 6               1970                1  2017-10-13    units     2.0
# 7               1970                1  2017-10-14    units     2.0
# 8               1970                1  2017-10-15    units     2.0
# 9               1970                1  2017-10-13   values  1620.0
# 10              1970                1  2017-10-14   values  1620.0
# 11              1970                1  2017-10-15   values  1620.0
# 12              1970                1  2016-03-29    units     2.0
# 13              1970                1  2016-03-29   values  1540.0
# 14              1970                1  2017-10-19    units     2.0
# 15              1970                1  2017-10-24    units     2.0
# 16              1970                1  2017-10-26    units     2.0
# 17              1970                1  2017-10-19   values  1620.0
# 18              1970                1  2017-10-24   values  1620.0
# 19              1970                1  2017-10-26   values  1620.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999998 entries, 0 to 1999997
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ProductFamily_ID    object
#  1   ProductCategory_ID  object
#  2   ProductBrand_ID     object
#  3   ProductName_ID      object
#  4   ProductPackSKU_ID   object
#  5   Point-of-Sale_ID    object
#  6   Date                object
#  7   Measures            object
#  8   Value               float64
# dtypes: float64(1), object(8)
# memory usage: 137.3+ MB

# %%
data['Date'] = pd.to_datetime(data['Date'])
#data = data.sort_values(by='Date')

# %%
# Creating a variable with the day of the week of each purchase

data['Day of the Week'] = data['Date'].dt.dayofweek

# %%
# Creating a variable with the correspondent quarter

data['Quarter'] = data['Date'].dt.quarter

# %%
# Splitting the dataframe based on Units/ Values

data_units = data[data['Measures'] == 'units']
data_values = data[data['Measures'] == 'values']

# %%
data_values = data_values.assign(Units=data_units['Value'].values)
data_values = data_values.drop(columns='Measures')

# %%
data_values.to_csv('values_units.csv.gz', compression='gzip')

# %% [markdown]
# ##### Loading the preprocessed dataset

# %%
dataPP =  pd.read_csv(pathPP)

# %%
plt.figure(figsize=(12,8))
sns.countplot(x="Day of the Week", data=dataPP, color='darkblue')
plt.ylabel('Count', fontsize=12)
plt.xlabel('Day of the week', fontsize=12)
plt.title("Frequency of purchase by day of the week", fontsize=15)
plt.show()

# %%
cnt = dataPP['ProductName_ID'].value_counts()[:10]
plt.figure(figsize=(12,8))
sns.barplot(cnt.values, cnt.index, alpha=0.8, color='gray')
plt.xlabel('Number of Occurrences', fontsize=12)
plt.ylabel('Product ID', fontsize=12)
plt.title("Top 10 products", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.distplot(dataPP['Value'], color='green')
plt.xlabel('Value', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.show()

# %%
data_values.head()
# Out:
#    ProductFamily_ID ProductCategory_ID ProductBrand_ID ProductName_ID  \
# 1                16                 11             306            649
# 3                16                 11             306            649
# 5                16                 11             306            649
# 9                16                 11             306            649
# 10               16                 11             306            649
#
#    ProductPackSKU_ID Point-of-Sale_ID       Date   Value  Day of the Week  \
# 1               1970                1 2017-03-04  1540.0                5
# 3               1970                1 2016-05-02  3080.0                0
# 5               1970                1 2016-10-24  1540.0                0
# 9               1970                1 2017-10-13  1620.0                4
# 10              1970                1 2017-10-14  1620.0                5
#
#     Quarter  Units
# 1         1    2.0
# 3         2    4.0
# 5         4    2.0
# 9         4    2.0
# 10        4    2.0

# %% [markdown]
# ### Point-of-sale

# %% [markdown]
# ####  Quarterly analysis
# ###### January, February, and March (Q1)
# ###### April, May, and June (Q2)
# ###### July, August, and September (Q3)
# ###### October, November, and December (Q4)

# %%
fig = px.line(dataPP.sort_values(by='Date'), x="Date", y="Value")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-14-fabb7ab1aacb> in <module>
# ----> 1 fig = px.line(dataPP.sort_values(by='Date'), x="Date", y="Value")
#       2 fig.show()
#
# ~\Anaconda3\lib\site-packages\plotly\express\_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     250     a polyline mark in 2D space.
#     251     """
# --> 252     return make_figure(args=locals(), constructor=go.Scatter)
#     253
#     254
#
# ~\Anaconda3\lib\site-packages\plotly\express\_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1859     apply_default_cascade(args)
#    1860
# -> 1861     args = build_dataframe(args, constructor)
#    1862     if constructor in [go.Treemap, go.Sunburst] and args["path"] is not None:
#    1863         args = process_dataframe_hierarchy(args)
#
# ~\Anaconda3\lib\site-packages\plotly\express\_core.py in build_dataframe(args, constructor)
#    1375     # now that things have been prepped, we do the systematic rewriting of `args`
#    1376
# -> 1377     df_output, wide_id_vars = process_args_into_dataframe(
#    1378         args, wide_mode, var_name, value_name
#    1379     )
#
# ~\Anaconda3\lib\site-packages\plotly\express\_core.py in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1196                 else:
#    1197                     col_name = str(argument)
# -> 1198                     df_output[col_name] = to_unindexed_series(df_input[argument])
#    1199             # ----------------- argument is likely a column / array / list.... -------
#    1200             else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3113         ensure homogeneity.
#    3114         """
# -> 3115         self._ensure_valid_index(value)
#    3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _ensure_valid_index(self, value)
#    3176                 index_copy.name = self.index.name
#    3177
# -> 3178             self._mgr = self._mgr.reindex_axis(index_copy, axis=1, fill_value=np.nan)
#    3179
#    3180     def _box_col_values(self, values, loc: int) -> Series:
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_axis(self, new_index, axis, method, limit, fill_value, copy)
#    1228         """
#    1229         new_index = ensure_index(new_index)
# -> 1230         new_index, indexer = self.axes[axis].reindex(
#    1231             new_index, method=method, limit=limit
#    1232         )
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in reindex(self, target, method, level, limit, tolerance)
#    3332                 # check is_overlapping for IntervalIndex compat
#    3333                 if self.is_unique and not getattr(self, "is_overlapping", False):
# -> 3334                     indexer = self.get_indexer(
#    3335                         target, method=method, limit=limit, tolerance=tolerance
#    3336                     )
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2978         if not is_dtype_equal(self.dtype, target.dtype):
#    2979             this = self.astype(object)
# -> 2980             target = target.astype(object)
#    2981             return this.get_indexer(
#    2982                 target, method=method, limit=limit, tolerance=tolerance
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in astype(self, dtype, copy)
#     664
#     665         try:
# --> 666             casted = self._values.astype(dtype, copy=copy)
#     667         except (TypeError, ValueError) as err:
#     668             raise TypeError(
#
# MemoryError: Unable to allocate 696. MiB for an array with shape (91171152,) and data type object

# %%
fig = px.bar(data_values, x="total_bill", y="day", orientation='h')
fig.show()
